# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os as os
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
import scipy as sp
from sklearn.preprocessing import MinMaxScaler
from scipy.special import boxcox1p
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve
from imblearn.under_sampling import *
from imblearn.over_sampling import *
from imblearn.combine import *

# %%
train = pd.read_csv('/content/drive/My Drive/datrain.csv')
test = pd.read_csv('/content/drive/My Drive/datest.csv')
sample_submission = pd.read_csv('/content/drive/My Drive/sample_submission.csv')

sample_submission.describe()
# Out:
#                   id  STAR_WHITE_DWARF  ...  SERENDIPITY_MANUAL  SERENDIPITY_BLUE
# count   10009.000000           10009.0  ...             10009.0           10009.0
# mean   204995.000000               0.0  ...                 0.0               0.0
# std      2889.493756               0.0  ...                 0.0               0.0
# min    199991.000000               0.0  ...                 0.0               0.0
# 25%    202493.000000               0.0  ...                 0.0               0.0
# 50%    204995.000000               0.0  ...                 0.0               0.0
# 75%    207497.000000               0.0  ...                 0.0               0.0
# max    209999.000000               0.0  ...                 0.0               0.0
#
# [8 rows x 20 columns]

# %%
test_id=test['id']

# %%
test = test.drop(columns=['fiberID'])

# %%
train_x = train.drop(columns=['id','type', 'fiberID'], axis=1)
train_y = train['type']
test_x = test
train_x
# Out:
#          psfMag_u   psfMag_g   psfMag_r  ...  modelMag_r  modelMag_i  modelMag_z
# 0       23.198224  21.431953  21.314148  ...   21.364187   21.020605   21.147340
# 1       21.431355  20.708104  20.678850  ...   20.753925   20.693389   20.512314
# 2       17.851451  16.727898  16.679677  ...   16.641249   16.660177   16.688928
# 3       20.789900  20.040371  19.926909  ...   19.889798   19.758113   19.552855
# 4       26.454969  23.058767  21.471406  ...   21.475342   19.487330   18.375655
# ...           ...        ...        ...  ...         ...         ...         ...
# 199986  20.630780  20.437920  20.050756  ...   20.014046   20.061940   19.862513
# 199987  25.283695  22.807243  21.069792  ...   19.776321   18.990039   18.528306
# 199988  23.609826  21.902709  20.330747  ...   20.420524   18.443126   17.331724
# 199989  21.172003  20.561208  20.031754  ...   17.440331   17.193743   16.969854
# 199990  20.624498  20.122276  20.332241  ...   20.327396   20.217198   19.995023
#
# [199991 rows x 20 columns]

# %%
train_y
# Out:
# 0                    QSO
# 1                    QSO
# 2                    QSO
# 3                    QSO
# 4         STAR_RED_DWARF
#                ...
# 199986               QSO
# 199987            GALAXY
# 199988    STAR_RED_DWARF
# 199989            GALAXY
# 199990               QSO
# Name: type, Length: 199991, dtype: object

# %%
# oversample = RandomOverSampler(sampling_strategy='minority')
# ST_train_x, ST_train_y = oversample.fit_resample(train_x, train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-98c13b1bf9fd> in <module>()
# ----> 1 x_over.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
ST=SMOTETomek()

ST_train_x,ST_train_y = ST.fit_sample(train_x,train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.model_selection import train_test_split
ST_X_train, ST_X_valid, ST_y_train, ST_y_valid = train_test_split(ST_train_x, ST_train_y, \
                                                  test_size=0.2, random_state=42, stratify = ST_train_y)

# %%
ST_X_train=pd.DataFrame(ST_X_train)
ST_X_train.columns=['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i', 'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i', 'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i', 'modelMag_z']
ST_X_train
# Out:
#          psfMag_u   psfMag_g   psfMag_r  ...  modelMag_r  modelMag_i  modelMag_z
# 0       17.793411  16.877125  16.551096  ...   16.561001   16.452778   16.408309
# 1       23.377052  23.009132  22.700892  ...   22.093144   22.859354   20.918839
# 2       21.619446  19.425953  17.920607  ...   17.913036   16.450792   15.656552
# 3       20.462775  19.424003  19.204332  ...   18.721976   18.419595   18.261287
# 4       19.334857  18.913335  19.154643  ...   19.207595   19.428308   19.594405
# ...           ...        ...        ...  ...         ...         ...         ...
# 754455  19.880188  19.636759  19.617921  ...   19.619869   19.572721   19.260588
# 754456  19.768891  19.505418  19.240700  ...   18.926836   19.639022   20.316774
# 754457  18.977626  18.646204  18.861009  ...   18.871855   19.091186   19.346547
# 754458  19.383783  19.342100  19.819172  ...   19.768493   20.032392   20.294518
# 754459  26.378203  23.216819  21.976597  ...   22.179655   19.522436   17.966846
#
# [754460 rows x 20 columns]

# %%
ST_X_valid=pd.DataFrame(ST_X_valid)
ST_X_valid.columns=[ 'psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i', 'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i', 'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i', 'modelMag_z']
ST_X_valid
# Out:
#          psfMag_u   psfMag_g   psfMag_r  ...  modelMag_r  modelMag_i  modelMag_z
# 0       19.535660  18.435234  17.958345  ...   17.964561   17.773510   17.706113
# 1       18.133594  16.956382  16.591058  ...   16.574591   16.437367   16.393991
# 2       19.651448  19.387744  19.735262  ...   19.728469   19.987023   20.378950
# 3       20.230906  20.050606  19.701350  ...   19.515540   19.937188   19.327168
# 4       17.289760  16.310679  15.977868  ...   15.997951   15.879018   15.856543
# ...           ...        ...        ...  ...         ...         ...         ...
# 188611  23.081497  23.290706  22.177917  ...   22.045459   19.318445   17.551076
# 188612  19.320670  19.128088  19.402685  ...   19.414282   19.717408   19.623880
# 188613  24.004270  22.220448  20.453250  ...   19.378071   18.677699   18.297877
# 188614  24.470459  24.895148  23.414779  ...   23.235776   20.623415   18.840658
# 188615  21.294503  19.620674  18.602305  ...   17.645966   17.162231   16.769170
#
# [188616 rows x 20 columns]

# %%
ST_y_train=pd.DataFrame(ST_y_train)
ST_y_valid=pd.DataFrame(ST_y_valid)

# %%
ST_y_valid
# Out:
#                          0
# 0               REDDEN_STD
# 1         SPECTROPHOTO_STD
# 2         STAR_WHITE_DWARF
# 3       SERENDIPITY_MANUAL
# 4         SPECTROPHOTO_STD
# ...                    ...
# 188611  SERENDIPITY_MANUAL
# 188612    STAR_WHITE_DWARF
# 188613  SERENDIPITY_MANUAL
# 188614    STAR_BROWN_DWARF
# 188615              GALAXY
#
# [188616 rows x 1 columns]

# %%
# %%time
xgb_non = XGBClassifier(n_estimators=100, n_jobs=-1,max_depth = 10, random_state=42)
xgb_non.fit(ST_X_train,ST_y_train, eval_set=[(ST_X_train, ST_y_train), (ST_X_valid, ST_y_valid)],early_stopping_rounds=30)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-merror:0.131909	validation_1-merror:0.140433
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 30 rounds.
# [1]	validation_0-merror:0.120823	validation_1-merror:0.129814
# [2]	validation_0-merror:0.116782	validation_1-merror:0.126166
# [3]	validation_0-merror:0.113015	validation_1-merror:0.122508
# [4]	validation_0-merror:0.109519	validation_1-merror:0.119666
# [5]	validation_0-merror:0.107567	validation_1-merror:0.117965
# [6]	validation_0-merror:0.105816	validation_1-merror:0.116708
# [7]	validation_0-merror:0.104603	validation_1-merror:0.115573
# [8]	validation_0-merror:0.103247	validation_1-merror:0.114375
# [9]	validation_0-merror:0.102	validation_1-merror:0.113188
# [10]	validation_0-merror:0.100684	validation_1-merror:0.112133
# [11]	validation_0-merror:0.099963	validation_1-merror:0.111401
# [12]	validation_0-merror:0.098934	validation_1-merror:0.110558
# [13]	validation_0-merror:0.097912	validation_1-merror:0.109837
# [14]	validation_0-merror:0.09701	validation_1-merror:0.109052
# [15]	validation_0-merror:0.096103	validation_1-merror:0.108241
# [16]	validation_0-merror:0.09534	validation_1-merror:0.10769
# [17]	validation_0-merror:0.094507	validation_1-merror:0.107053
# [18]	validation_0-merror:0.093662	validation_1-merror:0.106317
# [19]	validation_0-merror:0.092703	validation_1-merror:0.105548
# [20]	validation_0-merror:0.091957	validation_1-merror:0.104922
# [21]	validation_0-merror:0.091271	validation_1-merror:0.10436
# [22]	validation_0-merror:0.090577	validation_1-merror:0.103793
# [23]	validation_0-merror:0.08983	validation_1-merror:0.103226
# [24]	validation_0-merror:0.08909	validation_1-merror:0.102695
# [25]	validation_0-merror:0.088296	validation_1-merror:0.102091
# [26]	validation_0-merror:0.087561	validation_1-merror:0.101476
# [27]	validation_0-merror:0.086901	validation_1-merror:0.100771
# [28]	validation_0-merror:0.086282	validation_1-merror:0.10031
# [29]	validation_0-merror:0.085682	validation_1-merror:0.099822
# [30]	validation_0-merror:0.08501	validation_1-merror:0.09927
# [31]	validation_0-merror:0.084389	validation_1-merror:0.09856
# [32]	validation_0-merror:0.083774	validation_1-merror:0.097972
# [33]	validation_0-merror:0.083075	validation_1-merror:0.097404
# [34]	validation_0-merror:0.082366	validation_1-merror:0.09698
# [35]	validation_0-merror:0.081865	validation_1-merror:0.096683
# [36]	validation_0-merror:0.081149	validation_1-merror:0.096015
# [37]	validation_0-merror:0.080565	validation_1-merror:0.095437
# [38]	validation_0-merror:0.080023	validation_1-merror:0.095029
# [39]	validation_0-merror:0.079417	validation_1-merror:0.094578
# [40]	validation_0-merror:0.078847	validation_1-merror:0.09417
# [41]	validation_0-merror:0.078171	validation_1-merror:0.09355
# [42]	validation_0-merror:0.077544	validation_1-merror:0.092998
# [43]	validation_0-merror:0.076834	validation_1-merror:0.092521
# [44]	validation_0-merror:0.076379	validation_1-merror:0.092177
# [45]	validation_0-merror:0.07583	validation_1-merror:0.091737
# [46]	validation_0-merror:0.075304	validation_1-merror:0.091397
# [47]	validation_0-merror:0.074803	validation_1-merror:0.090947
# [48]	validation_0-merror:0.074314	validation_1-merror:0.090496
# [49]	validation_0-merror:0.073841	validation_1-merror:0.090045
# [50]	validation_0-merror:0.073356	validation_1-merror:0.089648
# [51]	validation_0-merror:0.072802	validation_1-merror:0.089202
# [52]	validation_0-merror:0.072399	validation_1-merror:0.088948
# [53]	validation_0-merror:0.072029	validation_1-merror:0.088662
# [54]	validation_0-merror:0.071606	validation_1-merror:0.088174
# [55]	validation_0-merror:0.071158	validation_1-merror:0.087744
# [56]	validation_0-merror:0.070587	validation_1-merror:0.087283
# [57]	validation_0-merror:0.070167	validation_1-merror:0.086933
# [58]	validation_0-merror:0.069778	validation_1-merror:0.086737
# [59]	validation_0-merror:0.069398	validation_1-merror:0.086239
# [60]	validation_0-merror:0.068978	validation_1-merror:0.085873
# [61]	validation_0-merror:0.068526	validation_1-merror:0.085587
# [62]	validation_0-merror:0.068163	validation_1-merror:0.085215
# [63]	validation_0-merror:0.067605	validation_1-merror:0.084818
# [64]	validation_0-merror:0.067269	validation_1-merror:0.084553
# [65]	validation_0-merror:0.066841	validation_1-merror:0.084145
# [66]	validation_0-merror:0.06647	validation_1-merror:0.083858
# [67]	validation_0-merror:0.066115	validation_1-merror:0.083752
# [68]	validation_0-merror:0.065758	validation_1-merror:0.083471
# [69]	validation_0-merror:0.065398	validation_1-merror:0.083217
# [70]	validation_0-merror:0.065012	validation_1-merror:0.082989
# [71]	validation_0-merror:0.064547	validation_1-merror:0.082676
# [72]	validation_0-merror:0.064238	validation_1-merror:0.082432
# [73]	validation_0-merror:0.063746	validation_1-merror:0.08213
# [74]	validation_0-merror:0.063268	validation_1-merror:0.081828
# [75]	validation_0-merror:0.062938	validation_1-merror:0.081642
# [76]	validation_0-merror:0.062555	validation_1-merror:0.081467
# [77]	validation_0-merror:0.062231	validation_1-merror:0.081133
# [78]	validation_0-merror:0.061881	validation_1-merror:0.08091
# [79]	validation_0-merror:0.061419	validation_1-merror:0.080523
# [80]	validation_0-merror:0.061081	validation_1-merror:0.080333
# [81]	validation_0-merror:0.060785	validation_1-merror:0.080163
# [82]	validation_0-merror:0.060553	validation_1-merror:0.079961
# [83]	validation_0-merror:0.060258	validation_1-merror:0.079702
# [84]	validation_0-merror:0.059867	validation_1-merror:0.079415
# [85]	validation_0-merror:0.05956	validation_1-merror:0.079166
# [86]	validation_0-merror:0.05929	validation_1-merror:0.078933
# [87]	validation_0-merror:0.059013	validation_1-merror:0.078636
# [88]	validation_0-merror:0.058611	validation_1-merror:0.078376
# [89]	validation_0-merror:0.05838	validation_1-merror:0.078185
# [90]	validation_0-merror:0.058133	validation_1-merror:0.078026
# [91]	validation_0-merror:0.057677	validation_1-merror:0.077724
# [92]	validation_0-merror:0.057322	validation_1-merror:0.07747
# [93]	validation_0-merror:0.056843	validation_1-merror:0.077194
# [94]	validation_0-merror:0.056423	validation_1-merror:0.076823
# [95]	validation_0-merror:0.056006	validation_1-merror:0.076478
# [96]	validation_0-merror:0.055714	validation_1-merror:0.07633
# [97]	validation_0-merror:0.055479	validation_1-merror:0.076118
# [98]	validation_0-merror:0.055114	validation_1-merror:0.075874
# [99]	validation_0-merror:0.054724	validation_1-merror:0.075699
# CPU times: user 4h 40min 4s, sys: 16.7 s, total: 4h 40min 21s
# Wall time: 2h 21min 1s

# %%
test=test.drop(columns=['id'],axis=1)

# %%
sample_submission.describe()
# Out:
#                   id  STAR_WHITE_DWARF  ...  SERENDIPITY_MANUAL  SERENDIPITY_BLUE
# count   10009.000000           10009.0  ...             10009.0           10009.0
# mean   204995.000000               0.0  ...                 0.0               0.0
# std      2889.493756               0.0  ...                 0.0               0.0
# min    199991.000000               0.0  ...                 0.0               0.0
# 25%    202493.000000               0.0  ...                 0.0               0.0
# 50%    204995.000000               0.0  ...                 0.0               0.0
# 75%    207497.000000               0.0  ...                 0.0               0.0
# max    209999.000000               0.0  ...                 0.0               0.0
#
# [8 rows x 20 columns]

# %%
XGB_pred = xgb_non.predict_proba(test)
submission = pd.DataFrame(data=XGB_pred)
submission= pd.concat([test_id,submission],axis=1)
submission.columns=sample_submission.columns
submission.to_csv('/content/drive/My Drive/XGBoost.csv', index=False)
submission.describe()
# Out:
#                   id  STAR_WHITE_DWARF  ...  SERENDIPITY_MANUAL  SERENDIPITY_BLUE
# count   10009.000000      10009.000000  ...        10009.000000      10009.000000
# mean   204995.000000          0.181112  ...            0.006249          0.022092
# std      2889.493756          0.376032  ...            0.074228          0.096650
# min    199991.000000          0.000011  ...            0.000004          0.000005
# 25%    202493.000000          0.000140  ...            0.000036          0.000126
# 50%    204995.000000          0.000283  ...            0.000127          0.000356
# 75%    207497.000000          0.001233  ...            0.000229          0.004847
# max    209999.000000          0.998825  ...            0.999338          0.945343
#
# [8 rows x 20 columns]
